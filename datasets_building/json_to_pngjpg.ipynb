# %%
#pip install labelme
import base64
import json
import os
import os.path as osp
import numpy as np
import PIL.Image
from labelme import utils
'''
Key considerations for creating custom semantic segmentation datasets:
1. The labelme version used is 3.16.7. This specific version is recommended as some other versions may cause errors,
   specifically: Too many dimensions: 3 > 2
   Installation command: pip install labelme==3.16.7
2. The generated label images are 8-bit color images, which appear different from the dataset format shown in videos.
   Although they appear as color images, they are actually only 8-bit, where each pixel value represents the class category.
   This format is identical to the VOC dataset format shown in videos. Therefore, datasets created this way are valid and functional.
'''
if __name__ == '__main__':
    jpgs_path = "C:/Users/12152/Desktop/datasets/JPEGImages"
    pngs_path = "C:/Users/12152/Desktop/datasets/SegmentationClass"
    # classes     = ["_background_","person", "car", "motorbike", "dustbin","chair","fire_hydrant","tricycle","bicycle","stone"]
    classes = ["_background_", "cuttlefish"]
    count = os.listdir("C:/Users/12152/Desktop/jsonfile")
    for i in range
