# %%
#pip install Augmentor
import Augmentor
from PIL import Image, ImageOps, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
Image.MAX_IMAGE_PIXELS = None
# Specify the original image storage path and mask file storage path (to change "\" to "/")
p = Augmentor.Pipeline("C:/Users/12152/Desktop/datasets/origin")
# p.ground_truth("C:/Users/12152/Desktop/datasets/segment")

# Image rotation: executed with probability 0.8, range between 0-25 degrees
# p.rotate(probability=0.8, max_left_rotation=25, max_right_rotation=25)

# # Image horizontal flip: executed with probability 0.5
# p.flip_left_right(probability=0.5)
# p.flip_top_bottom(probability=0.5)

# Image zoom: executed with probability 0.8, area is 0.85 times the original
# p.zoom_random(probability=0.3, percentage_area=0.7)

# scale_factor represents scaling ratio, must be greater than 1, and scales proportionally
# p.scale(probability=1, scale_factor=1.1)

# Local distortion
# p.random_distortion(probability=0.8, grid_width=10, grid_height=10, magnitude=20)

# Random shear: max_shear_left, max_shear_right represent shear transformation angles, range 0-25
# p.shear(probability=1, max_shear_left=10, max_shear_right=10)

# Random crop
# p.crop_random(probability=1, percentage_area=0.8, randomise_percentage_area=True)

# Random flip
# p.flip_random(probability=1)

# Random brightness enhancement/reduction, min_factor and max_factor are variation factors determining brightness change degree, can be specified based on desired effect
p.random_brightness(probability=1, min_factor=0.5, max_factor=2.0)

# Random color/contrast enhancement/reduction
# p.random_color(probability=1, min_factor=0.0, max_factor=1)
p.random_contrast(probability=1, min_factor=0.5, max_factor=2.0)

# Generate augmented samples (can be changed to 100, 1000, etc. as needed)
p.sample(15)
