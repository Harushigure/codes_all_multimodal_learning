# %%
# pip install matplotlib scikit-learn
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load features from previous steps
features_array = np.load("C:/Users/12152/Desktop/data/sepia2/features.npy")

# Ensure features_array is loaded correctly; 1200 is the total number of images, adjust according to actual data
if features_array.shape != (1200, 512):
    raise ValueError("Features array should have shape (1200, 512).")

scaler = StandardScaler()
features_array_standardized = scaler.fit_transform(features_array)

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)  # Reduce to 2 dimensions
embedding = pca.fit_transform(features_array_standardized)

# Define color rules (color gradients within each group); data consists of 200 frames per experimental treatment, totaling 6 groups with 1200 points
colors = []
for i in range(1200):
    if 0 <= i < 200:  # Red group (light red to dark red)
        colors.append((i - 0) / 199)  # Color value ranges from 0 to 1
    elif 200 <= i < 400:  # Orange group (light orange to dark orange)
        colors.append(((i - 200) / 199))  # Color value ranges from 0 to 1
    elif 400 <= i < 600:  # Yellow group (light yellow to dark yellow)
        colors.append(((i - 400) / 199))  # Color value ranges from 0 to 1
    elif 600 <= i < 800:  # Green group (light green to dark green)
        colors.append(((i - 600) / 199))  # Color value ranges from 0 to 1
    elif 800 <= i < 1000:  # Blue group (light blue to dark blue)
        colors.append(((i - 800) / 199))  # Color value ranges from 0 to 1
    else:  # Purple group (light purple to dark purple)
        colors.append(((i - 1000) / 199))  # Color value ranges from 0 to 1

# Create multiple independent colormaps such that points within each group transition from light to dark according to their chronological order. Color-treatment correspondence is shown in PPT
cmaps = [
    LinearSegmentedColormap.from_list("red", ["#FFAAAA", "#FF0000"], N=256),  # Light red to dark red
    LinearSegmentedColormap.from_list("orange", ["#FFCC99", "#F
# Out:
#   Cell In[1], line 40
#     LinearSegmentedColormap.from_list("orange", ["#FFCC99", "#F
#                                                             ^
# SyntaxError: unterminated string literal (detected at line 40)
